# %% [markdown]
# # Inspec dataset analysis
#
# The purpose of this notebook is to perform simple data exploration of `inspec` dataset. We want to perform a split of the dataset into two separate sets: test and train.
#
# Those two sets has to meet arbitraly chosen properties:
# * **Separate sets of keywords** - docs in those two sets has to have separate sets of keywords.
# * **One doc should be a part of multiple clusters**

# %% [markdown]
# ### Basic preparation

# %%
import pandas as pd
import numpy as np
import os
import re

from statistics import mean, median
from typing import List

# %%
DATASET_PATH = "../.dump/Inspec"

# %%
def clean_keyword(keyword: str) -> str:
  keyword = keyword.replace("\t", " ").replace("\n", " ").replace("\r", " ").replace("\f", " ").replace("\v", " ").strip().lower()
  keyword = re.sub(r'\s+', ' ', keyword)
  return keyword

def read_keywords() -> List[List[str]]:
  files = os.listdir(DATASET_PATH + "/keys")

  keywords: List[List[str]] = []

  for file in files:
        with open(DATASET_PATH + "/keys/" + file, "r") as f:
            keywords_list = f.read().splitlines()
            keywords_list = [clean_keyword(keyword) for keyword in keywords_list]
            keywords_list = list(set(keywords_list))
            keywords_list.sort()

            keywords.append(keywords_list)

  return keywords

# %%
def read_docs() -> List[str]:
    files = os.listdir(DATASET_PATH + "/docsutf8")

    docs: List[str] = []

    for file in files:
      with open(DATASET_PATH + "/docsutf8/" + file, "r") as f:
        docs.append(f.read())

    return docs

# %%
keywords = read_keywords()
docs = read_docs()

# %% [markdown]
# ## Basic analysis

# %%
keyword_counts = {}

for keyword_list in keywords:
  for keyword in keyword_list:
    if keyword not in keyword_counts:
      keyword_counts[keyword] = 0
    keyword_counts[keyword] += 1

# %%
keyword_counts = {k: v for k, v in sorted(keyword_counts.items(), key=lambda item: item[1], reverse=True)}



keyword_counts
# Out:
# {'internet': 148,
#  'information resources': 99,
#  'probability': 65,
#  'computational complexity': 64,
#  'optimisation': 58,
#  'medical image processing': 57,
#  'matrix algebra': 51,
#  'control system synthesis': 43,
#  'nonlinear control systems': 41,
#  'gender issues': 40,
#  'statistical analysis': 40,
#  'stability': 39,
#  'neural nets': 38,
#  'human factors': 38,
#  'academic libraries': 37,
#  'social aspects of automation': 36,
#  'computer science education': 36,
#  'library automation': 36,
#  'learning (artificial intelligence)': 36,
#  'psychology': 36,
#  'polynomials': 35,
#  'medical computing': 35,
#  'robust control': 35,
#  'iterative methods': 34,
#  'electronic commerce': 34,
#  'graph theory': 34,
#  'differential equations': 34,
#  'user interfaces': 33,
#  'feedback': 33,
#  'mobile computing': 32,
#  'decision theory': 31,
#  'business data processing': 31,
#  'digital simulation': 30,
#  'production control': 30,
#  'computational geometry': 29,
#  'electronic publishing': 28,
#  'closed loop systems': 28,
#  'image reconstruction': 28,
#  'finite element analysis': 28,
#  'quantum computing': 27,
#  'process control': 27,
#  'fuzzy logic': 27,
#  'simulation': 26,
#  'information systems': 26,
#  'linear systems': 26,
#  'optimal control': 25,
#  'wavelet transforms': 25,
#  'quantum theory': 25,
#  'genetic algorithms': 25,
#  'minimisation': 25,
#  'fuzzy set theory': 23,
#  'personnel': 23,
#  'interpolation': 23,
#  'teaching': 23,
#  'security of data': 22,
#  'information technology': 22,
#  'approximation theory': 22,
#  'women': 22,
#  'performance evaluation': 21,
#  'set theory': 21,
#  'convergence': 21,
#  'protocols': 20,
#  'employment': 20,
#  'marketing': 20,
#  'machining': 20,
#  'professional aspects': 20,
#  'law administration': 20,
#  'dp management': 20,
#  'information retrieval': 20,
#  'identification': 20,
#  'formal logic': 20,
#  'telecommunication': 20,
#  'parameter estimation': 19,
#  'investment': 19,
#  'nonlinear dynamical systems': 19,
#  'scheduling': 19,
#  'real-time systems': 19,
#  'inference mechanisms': 19,
#  'standards': 19,
#  'hypermedia markup languages': 19,
#  'human resource management': 18,
#  'image segmentation': 18,
#  'decision support systems': 18,
#  'management': 18,
#  'educational computing': 18,
#  'image coding': 18,
#  'health care': 18,
#  'operations research': 18,
#  'optimization': 18,
#  'object-oriented programming': 18,
#  'position control': 18,
#  'fuzzy control': 18,
#  'discrete time systems': 17,
#  'computer science': 17,
#  'data mining': 17,
#  'eigenvalues and eigenfunctions': 17,
#  'tracking': 17,
#  'information science': 17,
#  'data compression': 17,
#  'uncertain systems': 17,
#  'legislation': 17,
#  'artificial intelligence': 17,
#  'software agents': 17,
#  'multi-agent systems': 17,
#  'control system analysis': 17,
#  'biomedical mri': 17,
#  'chemistry computing': 17,
#  'economics': 16,
#  'telecommunication traffic': 16,
#  'parallel programming': 16,
#  'reliability': 16,
#  'search problems': 16,
#  'physics computing': 16,
#  'stochastic processes': 16,
#  'transport protocols': 16,
#  'calibration': 16,
#  'data analysis': 16,
#  'computer network management': 16,
#  'medical diagnostic imaging': 16,
#  'management information systems': 16,
#  'quantum communication': 16,
#  'filtering theory': 15,
#  'cryptography': 15,
#  'software packages': 15,
#  'adaptive control': 15,
#  'chaos': 15,
#  'machine tools': 15,
#  'client-server systems': 15,
#  'history': 15,
#  'linear programming': 15,
#  'nonlinear systems': 15,
#  'state feedback': 15,
#  'accounting': 15,
#  'groupware': 15,
#  'information theory': 15,
#  'records management': 15,
#  'vibration control': 15,
#  'biology computing': 15,
#  'radiation therapy': 14,
#  'partial differential equations': 14,
#  'game theory': 14,
#  'management science': 14,
#  'convergence of numerical methods': 14,
#  'markov processes': 14,
#  'telecommunication network routing': 14,
#  'publishing': 14,
#  'computerised tomography': 14,
#  'electronic mail': 14,
#  'java': 14,
#  'security': 13,
#  'intelligent control': 13,
#  'dosimetry': 13,
#  'compensation': 13,
#  'virtual reality': 13,
#  'image registration': 13,
#  'knowledge representation': 13,
#  'dynamic programming': 13,
#  'modelling': 13,
#  'piezoelectric actuators': 13,
#  'computer vision': 12,
#  'lyapunov methods': 12,
#  'neurocontrollers': 12,
#  'image resolution': 12,
#  'feature extraction': 12,
#  'fortran': 12,
#  'heuristic programming': 12,
#  'rendering (computer graphics)': 12,
#  'fluctuations': 12,
#  'cad/cam': 12,
#  'cutting': 12,
#  'variable structure systems': 12,
#  'image processing': 12,
#  'delays': 12,
#  'robustness': 12,
#  'world wide web': 12,
#  'fuzzy systems': 12,
#  'asymptotic stability': 12,
#  'damping': 12,
#  'backpropagation': 12,
#  'intelligent actuators': 12,
#  'stock control': 12,
#  'costing': 11,
#  'power system control': 11,
#  'runge-kutta methods': 11,
#  'physiological models': 11,
#  'error analysis': 11,
#  'image colour analysis': 11,
#  'boundary-value problems': 11,
#  'computer aided instruction': 11,
#  'cellular automata': 11,
#  'document handling': 11,
#  'diagnostic radiography': 11,
#  'temporal logic': 11,
#  'computer simulation': 11,
#  'inverse problems': 11,
#  'signal processing': 11,
#  'knowledge based systems': 11,
#  'pattern recognition': 11,
#  'project management': 11,
#  'continuous time systems': 10,
#  'linearisation techniques': 10,
#  'fault tolerant computing': 10,
#  'telecommunication security': 10,
#  'integration': 10,
#  'stock markets': 10,
#  'government data processing': 10,
#  'educational courses': 10,
#  'learning': 10,
#  'differentiation': 10,
#  'flexible manufacturing systems': 10,
#  'cellular radio': 10,
#  'workflow management software': 10,
#  'computer graphics': 10,
#  'web site': 10,
#  'dp industry': 10,
#  'initial value problems': 10,
#  'handicapped aids': 10,
#  'management of change': 10,
#  'database management systems': 10,
#  'convolution': 10,
#  'least squares approximations': 10,
#  'resource allocation': 10,
#  'electronic data interchange': 10,
#  'banking': 10,
#  'medical signal processing': 10,
#  'monte carlo methods': 10,
#  'risk management': 10,
#  'graphical user interfaces': 10,
#  'controllability': 10,
#  'classification': 10,
#  'digital libraries': 10,
#  'observers': 10,
#  'queueing theory': 10,
#  'authorisation': 10,
#  'formal specification': 10,
#  'web sites': 10,
#  'self-adjusting systems': 10,
#  'mechanical engineering computing': 10,
#  'intelligent structures': 10,
#  'integer programming': 10,
#  'theorem proving': 10,
#  'dynamics': 10,
#  'fault diagnosis': 10,
#  'telemedicine': 10,
#  'e-commerce': 9,
#  'large-scale systems': 9,
#  'multicast communication': 9,
#  'telecommunication computing': 9,
#  'quality of service': 9,
#  'closed-loop system': 9,
#  'manufacturing industries': 9,
#  'town and country planning': 9,
#  'topology': 9,
#  'number theory': 9,
#  'vectors': 9,
#  'integral equations': 9,
#  'operating systems (computers)': 9,
#  'discrete event simulation': 9,
#  'statistical mechanics': 9,
#  'entropy': 9,
#  'time series': 9,
#  'image classification': 9,
#  'principal component analysis': 9,
#  'survey': 9,
#  'trees (mathematics)': 9,
#  'neural networks': 9,
#  'asynchronous transfer mode': 9,
#  'time-varying systems': 9,
#  'time-domain analysis': 9,
#  'computerised numerical control': 9,
#  'information needs': 9,
#  'edge detection': 9,
#  'noise': 9,
#  'radial basis function networks': 9,
#  'machine control': 9,
#  'bound states': 9,
#  'information services': 9,
#  'correlation methods': 9,
#  'lung': 9,
#  'teleconferencing': 9,
#  'motion control': 9,
#  'medical information systems': 9,
#  'technological forecasting': 8,
#  'geometry': 8,
#  'storage management': 8,
#  'computer networks': 8,
#  'adaptive signal processing': 8,
#  'parallel algorithms': 8,
#  'advertising': 8,
#  'functions': 8,
#  'condition monitoring': 8,
#  'training': 8,
#  'mesh generation': 8,
#  'bifurcation': 8,
#  'transportation': 8,
#  'transfer functions': 8,
#  'case study': 8,
#  'gaussian noise': 8,
#  'business': 8,
#  'multimedia communication': 8,
#  'geographic information systems': 8,
#  'planning': 8,
#  'knowledge acquisition': 8,
#  'patient treatment': 8,
#  'query processing': 8,
#  'fault tolerance': 8,
#  'speech recognition': 8,
#  'frequency response': 8,
#  'circuit simulation': 8,
#  'h/sup infinity / control': 8,
#  'encoding': 8,
#  'travel industry': 8,
#  'libraries': 8,
#  'geophysics computing': 8,
#  'numerical analysis': 8,
#  'uncertainty handling': 8,
#  'online front-ends': 8,
#  'modeling': 8,
#  'education': 8,
#  'genetic algorithm': 8,
#  'switching circuits': 8,
#  'image recognition': 8,
#  'numerical stability': 8,
#  'hilbert spaces': 8,
#  'user interface': 8,
#  'algorithm theory': 8,
#  'telecommunication congestion control': 8,
#  'tuning': 8,
#  'railways': 8,
#  'constraint handling': 8,
#  'combinatorial mathematics': 8,
#  'formal verification': 8,
#  'petri nets': 8,
#  'purchasing': 8,
#  'message passing': 8,
#  'splines (mathematics)': 8,
#  'molecular biophysics': 8,
#  'distributed object management': 8,
#  'data privacy': 8,
#  'industrial robots': 8,
#  'government policies': 8,
#  'process algebra': 8,
#  'data visualisation': 8,
#  'courseware': 8,
#  'cognitive systems': 8,
#  'distributed processing': 7,
#  'maximum likelihood estimation': 7,
#  'neurophysiology': 7,
#  'local area networks': 7,
#  'systems analysis': 7,
#  'numerical solution': 7,
#  'moulding': 7,
#  'marketing data processing': 7,
#  'economic cybernetics': 7,
#  'motion estimation': 7,
#  'diseases': 7,
#  'out-of-print books': 7,
#  'computational linguistics': 7,
#  'image restoration': 7,
#  'poles and zeros': 7,
#  'remote sensing': 7,
#  'content management': 7,
#  'mammography': 7,
#  'inspection': 7,
#  'power engineering computing': 7,
#  'reasoning': 7,
#  'specification languages': 7,
#  'covariance matrices': 7,
#  'industrial property': 7,
#  'decidability': 7,
#  'voltage control': 7,
#  'bayes methods': 7,
#  'fuzzy neural nets': 7,
#  'tree data structures': 7,
#  'state estimation': 7,
#  'state-space methods': 7,
#  'functional programming': 7,
#  'sensitivity': 7,
#  'three-term control': 7,
#  'synchronisation': 7,
#  'wide area networks': 7,
#  'pattern classification': 7,
#  'enterprise resource planning': 7,
#  'newton method': 7,
#  'personal computing': 7,
#  'white noise': 7,
#  'multivariable control systems': 7,
#  'notebook computers': 7,
#  'ccd image sensors': 7,
#  'induction motor drives': 7,
#  'corporate modelling': 7,
#  'software performance evaluation': 7,
#  'solid modelling': 7,
#  'experiments': 7,
#  'hypermedia': 7,
#  'stochastic systems': 7,
#  'cataloguing': 7,
#  'brain': 7,
#  'intranets': 7,
#  'image sequences': 7,
#  'open systems': 7,
#  'performance': 7,
#  'structural engineering computing': 7,
#  'biomedical ultrasonics': 7,
#  'organic compounds': 7,
#  'c++ language': 7,
#  'accuracy': 7,
#  'information retrieval systems': 7,
#  'feedforward': 7,
#  'xml': 7,
#  'retailing': 7,
#  'application program interfaces': 7,
#  'software libraries': 7,
#  'contracts': 7,
#  'scientific information systems': 7,
#  'research libraries': 7,
#  'kalman filters': 6,
#  'decision trees': 6,
#  'predictive control': 6,
#  'vlsi': 6,
#  'cartography': 6,
#  'program compilers': 6,
#  'multimedia computing': 6,
#  'vector quantisation': 6,
#  'internet telephony': 6,
#  'mathematical programming': 6,
#  'adaptive systems': 6,
#  'artificial life': 6,
#  'piecewise linear techniques': 6,
#  'power system stability': 6,
#  'simulated annealing': 6,
#  'programming': 6,
#  'parallel processing': 6,
#  'usa': 6,
#  'control system': 6,
#  'biocontrol': 6,
#  'spectral analysis': 6,
#  'optical disc storage': 6,
#  'aircraft control': 6,
#  'systems re-engineering': 6,
#  'image texture': 6,
#  'formal languages': 6,
#  'civil engineering computing': 6,
#  'reachability analysis': 6,
#  'financial data processing': 6,
#  'invertors': 6,
#  'cancer': 6,
#  'series (mathematics)': 6,
#  'system recovery': 6,
#  'students': 6,
#  'certification': 6,
#  'public domain software': 6,
#  'politics': 6,
#  'digital control': 6,
#  'reliability theory': 6,
#  'relational databases': 6,
#  'adaptive filters': 6,
#  'power system analysis computing': 6,
#  'computer viruses': 6,
#  'customer relationship management': 6,
#  'knowledge engineering': 6,
#  'blood vessels': 6,
#  'ordinary differential equations': 6,
#  'video coding': 6,
#  'simulation results': 6,
#  'computer literacy': 6,
#  'computer based training': 6,
#  'discrete systems': 6,
#  'brain models': 6,
#  'vocabulary': 6,
#  'constraint theory': 6,
#  'data structures': 6,
#  'laminates': 6,
#  'bibliographies': 6,
#  'case-based reasoning': 6,
#  'haemodynamics': 6,
#  'computational fluid dynamics': 6,
#  'software': 6,
#  'distance learning': 6,
#  'control system analysis computing': 6,
#  'vibrations': 6,
#  'file servers': 6,
#  'transaction processing': 6,
#  'computability': 6,
#  'insurance': 6,
#  'random processes': 6,
#  'man-machine systems': 6,
#  'productivity': 6,
#  "buyer's guides": 6,
#  'building management systems': 6,
#  'computerised monitoring': 6,
#  'web services': 6,
#  'mathematical model': 6,
#  'management education': 6,
#  'road vehicles': 6,
#  'electric current control': 6,
#  'distributed systems': 6,
#  'scalability': 6,
#  'software engineering': 6,
#  'spatial filters': 6,
#  'mobile robots': 6,
#  'power system harmonics': 6,
#  'cad': 6,
#  'uncertainty': 6,
#  'reduced order systems': 6,
#  'concurrency control': 5,
#  'business communication': 5,
#  'public key cryptography': 5,
#  'temperature control': 5,
#  'very large databases': 5,
#  'search engines': 5,
#  'crosstalk': 5,
#  'visual communication': 5,
#  'tumours': 5,
#  'hotel industry': 5,
#  'cardiology': 5,
#  'patients': 5,
#  'special collections': 5,
#  'parallelising compilers': 5,
#  'transforms': 5,
#  'fms': 5,
#  'materials handling': 5,
#  'wavelet transform': 5,
#  'lattice theory': 5,
#  'recurrent neural nets': 5,
#  'nonlinear differential equations': 5,
#  'quantum optics': 5,
#  'public libraries': 5,
#  'control systems': 5,
#  'neural network': 5,
#  'equivalence classes': 5,
#  'children': 5,
#  'lower bounds': 5,
#  'fractals': 5,
#  'complexity': 5,
#  'evolutionary computation': 5,
#  'power generation control': 5,
#  'image representation': 5,
#  'process monitoring': 5,
#  'functional equations': 5,
#  'variational techniques': 5,
#  'indexing': 5,
#  'sensors': 5,
#  'minimization': 5,
#  'frequency-domain analysis': 5,
#  'software reviews': 5,
#  'low-power electronics': 5,
#  'image quality': 5,
#  'dc-dc power convertors': 5,
#  'adders': 5,
#  'parallel architectures': 5,
#  'software portability': 5,
#  'librarians': 5,
#  'gradient methods': 5,
#  'multilayer perceptrons': 5,
#  'objective function': 5,
#  'expert systems': 5,
#  'finance': 5,
#  'quality control': 5,
#  'sparse matrices': 5,
#  'middleware': 5,
#  'agriculture': 5,
#  'image enhancement': 5,
#  'image sampling': 5,
#  'uk': 5,
#  'mimo systems': 5,
#  'stators': 5,
#  'information architecture': 5,
#  'hpf': 5,
#  'database': 5,
#  'social sciences': 5,
#  'distributed algorithms': 5,
#  'numerical results': 5,
#  'parallel languages': 5,
#  'air conditioning': 5,
#  'metadata': 5,
#  'feedback control': 5,
#  'e-mail': 5,
#  'random noise': 5,
#  'meta data': 5,
#  'transform coding': 5,
#  'quantum cryptography': 5,
#  'quantum information processing': 5,
#  'invariance': 5,
#  'computational model': 5,
#  'difference equations': 5,
#  'special libraries': 5,
#  'medicine': 5,
#  'computer games': 5,
#  'deconvolution': 5,
#  'mathematical operators': 5,
#  'public administration': 5,
#  'software maintenance': 5,
#  'membership functions': 5,
#  'natural sciences computing': 5,
#  'manufacturing': 5,
#  'functional languages': 5,
#  'composite materials': 5,
#  'smart structures': 5,
#  'information industry': 5,
#  'extrapolation': 5,
#  'microactuators': 5,
#  'controllers': 5,
#  'fault detection': 5,
#  'reviews': 5,
#  'distributed databases': 5,
#  'spectroscopy computing': 5,
#  'harmonic distortion': 5,
#  'data acquisition': 5,
#  'software reusability': 5,
#  'software development management': 5,
#  'automobile industry': 5,
#  'microcomputer applications': 5,
#  'actuators': 5,
#  'problem solving': 5,
#  'visual perception': 5,
#  'pervasive computing': 5,
#  'behavioural sciences': 5,
#  'algorithm': 5,
#  'tree searching': 5,
#  'chemical technology': 5,
#  'sensitivity analysis': 5,
#  'jacobian matrices': 5,
#  'manufacturing resources planning': 5,
#  'computer aided production planning': 5,
#  'aerospace control': 4,
#  'sampled data systems': 4,
#  'speaker recognition': 4,
#  'broadband networks': 4,
#  'video on demand': 4,
#  'design': 4,
#  'demography': 4,
#  'mobile communication': 4,
#  'cache storage': 4,
#  'positron emission tomography': 4,
#  'intensity modulation': 4,
#  'treatment planning': 4,
#  'error statistics': 4,
#  'manipulator dynamics': 4,
#  'return on investment': 4,
#  'socio-economic effects': 4,
#  'matrix decomposition': 4,
#  'stereo image processing': 4,
#  'nonlinear programming': 4,
#  'decoding': 4,
#  'discrete wavelet transforms': 4,
#  'hidden markov models': 4,
#  'wear': 4,
#  'electrocardiography': 4,
#  'linguistics': 4,
#  'quantum computation': 4,
#  'law firms': 4,
#  'flexible manufacturing system': 4,
#  'parallel computing': 4,
#  'quantum computers': 4,
#  'finite automata': 4,
#  'linearization': 4,
#  'parabolic equations': 4,
#  'compatibility': 4,
#  'optimising compilers': 4,
#  'nuclear magnetic resonance': 4,
#  'quantum gates': 4,
#  'arc welding': 4,
#  'unsupervised learning': 4,
#  'efficiency': 4,
#  'forecasting theory': 4,
#  'biochemistry': 4,
#  'velocity control': 4,
#  'copy protection': 4,
#  'data integrity': 4,
#  'noise level': 4,
#  'linear quadratic regulator': 4,
#  'medical expert systems': 4,
#  'object-oriented methods': 4,
#  'oscillations': 4,
#  'message authentication': 4,
#  'network topology': 4,
#  'degrees of freedom': 4,
#  'computer network reliability': 4,
#  'least mean squares methods': 4,
#  'polynomial approximation': 4,
#  'object recognition': 4,
#  'infrared imaging': 4,
#  'information processing': 4,
#  'electricity supply industry': 4,
#  'active filters': 4,
#  'power harmonic filters': 4,
#  'disasters': 4,
#  'biotechnology': 4,
#  'experiment': 4,
#  'digital signal processing chips': 4,
#  'processor scheduling': 4,
#  'hybrid systems': 4,
#  'experimental results': 4,
#  'error compensation': 4,
#  'computer program': 4,
#  'fir filters': 4,
#  'rapid prototyping (industrial)': 4,
#  'logic design': 4,
#  'shared memory systems': 4,
#  'computerised control': 4,
#  'rendering': 4,
#  'monotonicity': 4,
#  'network servers': 4,
#  'directed graphs': 4,
#  'knowledge management': 4,
#  'organization': 4,
#  'computer software': 4,
#  'graphs': 4,
#  'feedforward neural nets': 4,
#  'accreditation': 4,
#  'power supply quality': 4,
#  'diagnostic expert systems': 4,
#  'databases': 4,
#  'hypercube networks': 4,
#  'music': 4,
#  'gaussian processes': 4,
#  'image analysis': 4,
#  'pipeline processing': 4,
#  'high-speed integrated circuits': 4,
#  'elliptic equations': 4,
#  'sequences': 4,
#  'manipulators': 4,
#  'positioning': 4,
#  'shape memory effects': 4,
#  'computers': 4,
#  'it': 4,
#  'torque control': 4,
#  'correlation': 4,
#  'video signal processing': 4,
#  'banach spaces': 4,
#  'data visualization': 4,
#  'dynamic response': 4,
#  'entanglement': 4,
#  'mathematics computing': 4,
#  'government': 4,
#  'interoperability': 4,
#  'transient response': 4,
#  'decision support system': 4,
#  'microprocessor chips': 4,
#  'fuzzy rules': 4,
#  'embedded systems': 4,
#  'manufacturing processes': 4,
#  'performance measures': 4,
#  'organizations': 4,
#  'diagrams': 4,
#  'power system simulation': 4,
#  'images': 4,
#  'failure analysis': 4,
#  'distributed programming': 4,
#  'mean square error methods': 4,
#  'military systems': 4,
#  'optical fibre networks': 4,
#  'bending': 4,
#  'copyright': 4,
#  'personal computer': 4,
#  'software standards': 4,
#  'heuristics': 4,
#  'fidelity': 4,
#  'decision making': 4,
#  'technology': 4,
#  'road traffic': 4,
#  'simulations': 4,
#  'throughput': 4,
#  'ergonomics': 4,
#  'information dissemination': 4,
#  'power station control': 4,
#  'medical administrative data processing': 4,
#  'pharmaceutical industry': 4,
#  'spatial resolution': 4,
#  'packet switching': 4,
#  'pwm power convertors': 4,
#  'fuzzy modeling': 4,
#  'goods distribution': 4,
#  'interactive systems': 4,
#  'light interferometry': 4,
#  'group theory': 4,
#  'boolean functions': 4,
#  'automata theory': 4,
#  'bisimulation equivalence': 4,
#  'friction': 4,
#  'linear system': 4,
#  'grammars': 4,
#  'type theory': 4,
#  'proteins': 4,
#  'natural language processing': 4,
#  'html': 4,
#  'lower bound': 4,
#  'fractional differentiation': 4,
#  'outsourcing': 4,
#  'wireless lan': 4,
#  'power electronics': 4,
#  'switching frequency': 4,
#  'manufacturing data processing': 4,
#  'design of experiments': 4,
#  'europe': 4,
#  'np-complete problem': 4,
#  'product development': 4,
#  'united states': 4,
#  'minimax techniques': 4,
#  'hilbert space': 4,
#  'automation': 4,
#  'conjugate gradient methods': 4,
#  'eigenvalues': 4,
#  'chemical structure': 4,
#  'molecular configurations': 4,
#  'distributed control': 4,
#  'surgery': 4,
#  'numerical simulation': 4,
#  'nonlinear equations': 4,
#  'teachers': 4,
#  'microfluidics': 4,
#  'atm networks': 4,
#  'data warehouses': 4,
#  'kidney': 4,
#  'negotiation': 4,
#  'phase transformations': 4,
#  'india': 4,
#  'finite state machines': 4,
#  'statistics': 4,
#  'hysteresis': 4,
#  'nuclear engineering computing': 4,
#  'polynomial': 4,
#  'genetics': 4,
#  'web': 4,
#  'active noise control': 4,
#  'abb': 4,
#  'measurement errors': 4,
#  'time complexity': 4,
#  'image compression': 4,
#  'control design': 4,
#  'control performance': 4,
#  'iterative algorithm': 4,
#  'vibration measurement': 4,
#  'concurrent engineering': 4,
#  'heat transfer': 3,
#  'engineering': 3,
#  'gaussian distribution': 3,
#  'gaussian mixture model': 3,
#  'public key infrastructure': 3,
#  'optical logic': 3,
#  'optical modulation': 3,
#  'exponential distribution': 3,
#  'self-organising feature maps': 3,
#  'light interferometers': 3,
#  'system complexity': 3,
#  'construction industry': 3,
#  'taiwan': 3,
#  'power distribution control': 3,
#  'boolean algebra': 3,
#  'research initiatives': 3,
#  'intensity modulated radiation therapy': 3,
#  'logic testing': 3,
#  'factory automation': 3,
#  'network operating systems': 3,
#  'operator splitting': 3,
#  'cost': 3,
#  'microlenses': 3,
#  'micromachining': 3,
#  'geophysical signal processing': 3,
#  'terrain mapping': 3,
#  'quantisation (signal)': 3,
#  'econophysics': 3,
#  'discrete wavelet transform': 3,
#  'continuing education': 3,
#  'culture': 3,
#  'natural languages': 3,
#  'compiler': 3,
#  'decision analysis': 3,
#  'power system dynamic stability': 3,
#  'algebra': 3,
#  'artificial neural networks': 3,
#  'colour graphics': 3,
#  'workflow': 3,
#  'linear equations': 3,
#  'many-body problems': 3,
#  'programmable controllers': 3,
#  'mobile devices': 3,
#  'microcontrollers': 3,
#  'academic library': 3,
#  'deformation': 3,
#  'smoothing methods': 3,
#  'forecasting': 3,
#  'foreign exchange trading': 3,
#  'biological techniques': 3,
#  'profitability': 3,
#  'two-term control': 3,
#  'copyright protection': 3,
#  'storage requirements': 3,
#  'research': 3,
#  'manufacturers': 3,
#  'linear quadratic control': 3,
#  'real estate data processing': 3,
#  'computational cost': 3,
#  'delay systems': 3,
#  'logic cad': 3,
#  'biological tissues': 3,
#  'cost-benefit analysis': 3,
#  'maintenance engineering': 3,
#  'data management': 3,
#  'intelligent design assistants': 3,
#  'internet protocol multicast': 3,
#  'ip multicast': 3,
#  'network routers': 3,
#  'color images': 3,
#  'diffusion': 3,
#  'metallurgical industries': 3,
#  'text analysis': 3,
#  'distance measurement': 3,
#  'surface fitting': 3,
#  'acoustic signal processing': 3,
#  'array signal processing': 3,
#  'customer service': 3,
#  'portable computers': 3,
#  'intellectual property': 3,
#  'videoconferencing': 3,
#  'businesses': 3,
#  'information storage': 3,
#  'banks': 3,
#  'recovery': 3,
#  'production': 3,
#  'autoregressive processes': 3,
#  'electroencephalography': 3,
#  'power consumption': 3,
#  'frequency-domain synthesis': 3,
#  'cmos memory circuits': 3,
#  'software selection': 3,
#  'logic programming': 3,
#  'digital arithmetic': 3,
#  'nonlinear dynamics': 3,
#  'sales': 3,
#  'automatic test equipment': 3,
#  'finite difference methods': 3,
#  'library collections': 3,
#  'literature': 3,
#  "chua's circuit": 3,
#  'control': 3,
#  'high performance fortran': 3,
#  'boundary conditions': 3,
#  'cellular neural nets': 3,
#  'power transmission lines': 3,
#  'finite element method': 3,
#  'tax preparation': 3,
#  'zeros': 3,
#  'faculty': 3,
#  'interlibrary loan': 3,
#  'software tools': 3,
#  'emotion': 3,
#  'image morphing': 3,
#  'temperature distribution': 3,
#  'crisis management': 3,
#  'graphical user interface': 3,
#  'estimation theory': 3,
#  'pneumatic control equipment': 3,
#  'valves': 3,
#  'circuit cad': 3,
#  'control theory': 3,
#  "young's modulus": 3,
#  'fourier transforms': 3,
#  'document image processing': 3,
#  'adaptive filtering': 3,
#  'university': 3,
#  'group processes': 3,
#  'convex programming': 3,
#  'engineering computing': 3,
#  'human resources': 3,
#  'image motion analysis': 3,
#  'outliers': 3,
#  'complex systems': 3,
#  'analogue-digital conversion': 3,
#  'observability': 3,
#  'nonlinear network analysis': 3,
#  'cmos integrated circuits': 3,
#  'convergence speed': 3,
#  'microsoft': 3,
#  'external disturbances': 3,
#  'stabilization': 3,
#  'literature review': 3,
#  'digital library': 3,
#  'dynamic behavior': 3,
#  'user modelling': 3,
#  'injection moulding': 3,
#  'importance sampling': 3,
#  'transient analysis': 3,
#  'document management': 3,
#  'technology transfer': 3,
#  'scientific computing': 3,
#  'heat conduction': 3,
#  'inverse problem': 3,
#  'relaxation theory': 3,
#  'system architecture': 3,
#  'smart cards': 3,
#  'standardisation': 3,
#  'information architects': 3,
#  'end users': 3,
#  'piecewise constant techniques': 3,
#  'educational technology': 3,
#  'speech processing': 3,
#  'environmental science computing': 3,
#  'knowledge-based system': 3,
#  ...}

# %%
keyword_sets_counts = {}

for keyword_list in keywords:
  keyword_set = frozenset(keyword_list)
  if keyword_set not in keyword_sets_counts:
    keyword_sets_counts[keyword_set] = 0
  keyword_sets_counts[keyword_set] += 1

# %%
for keyword_set, count in keyword_sets_counts.items():
  if count > 1:
    print(keyword_set, count)

# %% [markdown]
# Apparently, there are no two docs with the same set of keywords.

# %%
keyword_occurences = {}

for i in range(len(keywords)):
  for keyword in keywords[i]:
    if keyword in keyword_occurences:
      keyword_occurences[keyword].append(i)
    else:
      keyword_occurences[keyword] = [i]

# %%
def analyse_keywords_occurences(keyword_occurences: dict[str, List[int]]):
  for i in range(1, 10):
    _keyword_occurences = {k: v for k, v in keyword_occurences.items() if len(v) >= i}

    # let's check how many unique ids are in pairs
    _unique_ids = set()
    for pair, ids in _keyword_occurences.items():
      _unique_ids.update(ids)

    print(f"For at least {i} occurences:")
    print(f"Unique ids: {len(_unique_ids)}")
    print(f"Total: {len(_keyword_occurences)}")
    print("--------")

# %%
analyse_keywords_occurences(keyword_occurences)
# Out:
# For at least 1 occurences:
# Unique ids: 2000
# Total: 18410
# --------
# For at least 2 occurences:
# Unique ids: 1992
# Total: 2165
# --------
# For at least 3 occurences:
# Unique ids: 1981
# Total: 1182
# --------
# For at least 4 occurences:
# Unique ids: 1967
# Total: 835
# --------
# For at least 5 occurences:
# Unique ids: 1943
# Total: 625
# --------
# For at least 6 occurences:
# Unique ids: 1917
# Total: 505
# --------
# For at least 7 occurences:
# Unique ids: 1879
# Total: 416
# --------
# For at least 8 occurences:
# Unique ids: 1849
# Total: 345
# --------
# For at least 9 occurences:
# Unique ids: 1810
# Total: 282
# --------

# %%
lengths = []

for key in keyword_occurences:
  lengths.append(len(keyword_occurences[key]))

# %%
print(f"Median of keyword occurences: {median(lengths)}")
print(f"Mean of keyword occurences: {mean(lengths)}")
# Out:
# Median of keyword occurences: 1.0
# Mean of keyword occurences: 1.480391091797936

# %%
docs_neighbours = {}

for keyword_list in keywords:
  for keyword in keyword_list:
    for doc_id in keyword_occurences[keyword]:
      if doc_id not in docs_neighbours:
        docs_neighbours[doc_id] = set()
      docs_neighbours[doc_id].update(keyword_occurences[keyword])

# %%
lengths = []

for key in docs_neighbours:
  lengths.append(len(docs_neighbours[key]))

print(f"Median of document neighbours: {median(lengths)}")
print(f"Mean of document neighbours: {mean(lengths)}")
# Out:
# Median of document neighbours: 53.0
# Mean of document neighbours: 67.048

# %%
vertices = set(range(len(docs)))
dfs_queue = []
graphs = []

while len(vertices) > 0:
  vertex = vertices.pop()
  dfs_queue.append(vertex)
  inner_graph = set()

  while len(dfs_queue) > 0:
    vertex = dfs_queue.pop()
    inner_graph.add(vertex)
    for neighbour in docs_neighbours[vertex]:
      if neighbour in vertices:
        dfs_queue.append(neighbour)
        vertices.remove(neighbour)
  
  graphs.append(inner_graph)

for graph in graphs:
  print(len(graph))
# Out:
# 1988
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 2

# %% [markdown]
# ## Conclusions
#
# That means that we've got one big connected graph inside of our docs graph if we treat docs as vertices and keywords as edges between them. We could probably remove some cut edges to make more connected graphs, but I guess it doesn't make sense. Removing a keyword would still mean that we would have two similar docs in separate sets (test and train).
#
# Presumably, we should just split the dataset into two separate sets and that's it, just making sure that we don't have the same doc in all sets

# %% [markdown]
# ## Keywords choice
#
# Let's verify how many pairs and triples of keywords occur in multiple docs.

# %%
pairs_ids = {}

for doc_id in range(len(keywords)):
  docs_keywords = keywords[doc_id]
  for i in range(len(docs_keywords)):
    for j in range(i + 1, len(docs_keywords)):
      pair = (docs_keywords[i], docs_keywords[j])
      if pair not in pairs_ids:
        pairs_ids[pair] = [doc_id]
      else:
        pairs_ids[pair].append(doc_id)

analyse_keywords_occurences(pairs_ids)
# Out:
# For at least 1 occurences:
# Unique ids: 2000
# Total: 205452
# --------
# For at least 2 occurences:
# Unique ids: 1651
# Total: 3831
# --------
# For at least 3 occurences:
# Unique ids: 1206
# Total: 970
# --------
# For at least 4 occurences:
# Unique ids: 924
# Total: 456
# --------
# For at least 5 occurences:
# Unique ids: 714
# Total: 252
# --------
# For at least 6 occurences:
# Unique ids: 566
# Total: 159
# --------
# For at least 7 occurences:
# Unique ids: 479
# Total: 95
# --------
# For at least 8 occurences:
# Unique ids: 406
# Total: 68
# --------
# For at least 9 occurences:
# Unique ids: 351
# Total: 48
# --------

# %%
triples_ids = {}

for doc_id in range(len(keywords)):
  docs_keywords = keywords[doc_id]
  for i in range(len(docs_keywords)):
    for j in range(i + 1, len(docs_keywords)):
      for k in range(j + 1, len(docs_keywords)):
        pair = (docs_keywords[i], docs_keywords[j], docs_keywords[k])
        if pair not in triples_ids:
          triples_ids[pair] = [doc_id]
        else:
          triples_ids[pair].append(doc_id)

analyse_keywords_occurences(triples_ids)
# Out:
# For at least 1 occurences:
# Unique ids: 1996
# Total: 1229994
# --------
# For at least 2 occurences:
# Unique ids: 779
# Total: 2637
# --------
# For at least 3 occurences:
# Unique ids: 349
# Total: 324
# --------
# For at least 4 occurences:
# Unique ids: 229
# Total: 107
# --------
# For at least 5 occurences:
# Unique ids: 145
# Total: 57
# --------
# For at least 6 occurences:
# Unique ids: 115
# Total: 27
# --------
# For at least 7 occurences:
# Unique ids: 77
# Total: 12
# --------
# For at least 8 occurences:
# Unique ids: 49
# Total: 8
# --------
# For at least 9 occurences:
# Unique ids: 35
# Total: 5
# --------

# %% [markdown]
# It seems that there are not many pairs or triples keyowrds that occur in multiple docs. That means that we should rely on single keywords.
